# %%
import numpy as np
import pandas as pd
import os  
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import io
import dateutil
import collections
import time
from datetime import datetime
import wrds
import networkx as nx

# %%
pd.set_option('display.max_rows',1000)

# %%
db = wrds.Connection() #connect to Wharton DB
# Out:
# Enter your WRDS username [ahardy12]:ahardy12
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
list_libraries = db.list_libraries()  #list all libraries in Wharton DB
list_libraries
# Out:
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_audit_comp',
#  'audit_corp_legal',
#  'block',
#  'boardex',
#  'boardex_na',
#  'boardex_trial',
#  'bvd',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'centris',
#  'ciq',
#  'ciq_capstrct',
#  'ciq_common',
#  'ciq_keydev',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'clrvt',
#  'clrvtsmp',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'compa',
#  'compb',
#  'compbd',
#  'compdcur',
#  'compg',
#  'compgd',
#  'compm',
#  'compnad',
#  'compsamp_snapshot',
#  'compseg',
#  'compsegd',
#  'compsnap',
#  'contrib',
#  'contrib_char_returns',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_stock',
#  'crsp_a_ziman',
#  'crsp_q_mutualfunds',
#  'crspa',
#  'crspm',
#  'crspq',
#  'djones',
#  'dmef',
#  'doe',
#  'etfg_samp',
#  'etfgsamp',
#  'eureka',
# ...

# %%
ciq_tables = db.list_tables(library="compnad") # List all tables in the compustat North America db
#Using the funda table from compnad, this table is Fundamentals Annual 
#ciq_tables

# %%
Full_dataset = db.raw_sql('select * from compnad.funda LIMIT 3;', index_col=['gvkey'])
#Select * from compnad.funda using gvkey as the index column

# %%
Full_dataframe = Full_dataset

# %%
Full_dataframe
# Out:
#           datadate   fyear indfmt consol popsrc datafmt   tic      cusip  \
# gvkey
# 001000  1961-12-31  1961.0   INDL      C      D     STD  AE.2  000032102
# 001000  1962-12-31  1962.0   INDL      C      D     STD  AE.2  000032102
# 001000  1963-12-31  1963.0   INDL      C      D     STD  AE.2  000032102
#
#                          conm acctchg  ...   prcc_f prch_f prcl_f   adjex_f  \
# gvkey                                  ...
# 001000  A & E PLASTIK PAK INC    None  ...     None   None   None  3.341831
# 001000  A & E PLASTIK PAK INC    None  ...     None   None   None  3.341831
# 001000  A & E PLASTIK PAK INC    None  ...     None   None   None  3.244497
#
#         rank    au  auop auopic ceoso  cfoso
# gvkey
# 001000  None  None  None   None  None   None
# 001000  None  None  None   None  None   None
# 001000  None  None  None   None  None   None
#
# [3 rows x 947 columns]
